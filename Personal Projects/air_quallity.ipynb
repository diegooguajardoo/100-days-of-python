# %%
import pandas as pd

import matplotlib.pyplot as plt

# %%
air_quality = pd.read_csv("/Users/diegoo.guajardoo/Documents/VS Code Studio/Data/Databases/air_quality_no2.csv",
                          index_col=0, parse_dates=True)

# %%
air_quality.columns
# Out:
# Index(['station_antwerp', 'station_paris', 'station_london'], dtype='object')

# %%
air_quality.plot.scatter(x="station_london", y="station_paris", alpha=0.5)
# Out:
# <AxesSubplot: xlabel='station_london', ylabel='station_paris'>

# %%
fig, axs = plt.subplots(figsize=(22, 5))

air_quality.plot.area(ax=axs)


axs.set_ylabel("NO$_2$ concentration")


fig.savefig("no2_concentrations.png")

plt.show()
